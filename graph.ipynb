# %%
with open('test-02.xyz.dump', 'r') as file, open('data_1.csv','w') as data_file_1, open('data_2.csv','w') as data_file_2:
    for line in file:
        line = line.strip().split()
        if len(line) == 7:
            if line[0] == '1':
                data_file_1.write(str(line[1] + ',' + line[4])+ '\n')
            else:
                data_file_2.write(str(line[1] + ',' + line[4]) + '\n')

# %%
import pandas as pd
import numpy as nu
import matplotlib.pyplot as plt

# %%
data_set_1 = pd.read_csv('data_1.csv',header=None)
data_set_2 = pd.read_csv('data_2.csv',header=None)

data_set_1.columns = ['x', 'Vx']
data_set_2.columns = ['x', 'Vx']

# %%
data_set_1
# Out:
#              x       Vx
# 0     0.500000  0.00200
# 1     0.700000  0.00200
# 2     0.900000  0.00200
# 3     1.100000  0.00200
# 4     1.300000  0.00200
# ...        ...      ...
# 996   0.997962 -0.00228
# 997   0.769920 -0.00228
# 998   0.541879 -0.00228
# 999   0.313838 -0.00228
# 1000  0.085797 -0.00228
#
# [1001 rows x 2 columns]

# %%
data_set_1.describe()
# Out:
#                  x           Vx
# count  1001.000000  1001.000000
# mean      6.829455    -0.000005
# std       4.381911     0.002669
# min       0.009310    -0.003319
# 25%       3.147309    -0.002830
# 50%       6.452691     0.000189
# 75%       9.716412     0.002966
# max      18.354705     0.003319

# %%
data_set_2.describe()
# Out:
#                  x           Vx
# count  1001.000000  1001.000000
# mean     14.611045    -0.000002
# std       3.460386     0.001541
# min       5.925543    -0.002449
# 25%      12.106425    -0.000935
# 50%      14.965632     0.000681
# 75%      17.523908     0.000935
# max      19.997738     0.002449

# %%
plt.figure(figsize=(24, 7))
plt.subplot(131)
plt.plot(data_set_1.x, 'r--', linewidth=2.0, label='x(t)')
plt.title('X(t)')
plt.xlabel('t')
plt.ylabel('X')




plt.subplot(132)
plt.plot(data_set_1.Vx, 'r--', linewidth=2.0)
plt.title('Vx(t)')
plt.xlabel('t')
plt.ylabel('Vx')



plt.show()

# %%
plt.figure(figsize=(24, 7))
plt.subplot(131)
plt.plot(data_set_2.x, '--', linewidth=2.0, label='x(t)')
plt.title('X(t)')
plt.xlabel('t')
plt.ylabel('X')




plt.subplot(132)
plt.plot(data_set_1.Vx, '--', linewidth=2.0)
plt.title('Vx(t)')
plt.xlabel('t')
plt.ylabel('Vx')



plt.show()
